# %%
# Click into this cell and press shift-enter before using this notebook.
# This line loads the ability to use %%ai in your file
# %load_ext jupyter_ai_magics
# This line loads the data science library; the * means "everything"
from datascience import *
import math

# %% [markdown]
# # CMPSC 5A, S25, lab01
#
# In last week's lab, we got you started with some basics about:
# * Opening up a Jupyter Notebook on the Jupyter Hub
# * Reading through the instructions
# * Adding Markdown cells and Code cells for AI prompts.
#
# In this week's lab, we'll first go over how the rest of the labs this quarter will go.
#
# Then you'll complete five questions, labelled Q1, Q2, Q3, and Q4
#
# When finished, you'll submit your lab on Gradescope.

# %% [markdown]
# # Attendance Check (ic05)
#
# **Before you continue, please complete the brief exercise on Gradescope labelled ic05**.

# %% [markdown]
# # How the labs work in CMPSC 5A
#
# You can't learn technical subjects without hands-on practice, so labs are an important part of the course.
#
# Before we get started, there are some administrative details.
#
# The weekly lab session has two components: questions and discussion (not using the computer) about recent material, and a lab assignment (like this one!) that develops skills with data science concepts.
#
# In addition to that, you will get familiar with programming in Python, interact with LLMs and learn how to write useful prompts, all while analyzing data! These lab assignments are a required part of the course and will be released on Wednesdays during lab time.
#
# Lab sessions are not recorded.
#
# Collaborating on labs is more than okay--it's encouraged! You should rarely remain stuck for more than a few minutes on questions in labs, so ask a neighbor, an LA or a TA for help.
#
# Explaining things to your fellow students is beneficial, too -- the best way to solidify your knowledge of a subject is to explain it.  Please don't *just share answers*, though. Instead, talk through your understanding of the problem, and try to help one another without giving away the answers.  When you discuss with others, do so with an intent to *help them learn*, not to help them *avoid learning*.

# %% [markdown]
# ## About Jupyter Notebooks
#
# As we discussed last week, there are three types of cells in a Jupyter Notebook, and the cell types are changed using the menu that looks like this:

# %% [markdown]
# ![lab01-cell-menu.png](attachment:bc0f35fe-e234-426f-94ff-b7a776c70402.png)

# %% [markdown]
# ## Markdown Cells
#
# In a notebook, each rectangle containing text or code is called a cell.
#
# Markdown cells (like this one) can be edited by double-clicking on them. They're written in a simple format called Markdown to add formatting and section headings.
#
# You are not required to become a Markdown expert, but you are encourage to learn a little bit of Markdown so that you'll be able to express yourself in the text cells you put in your notebook.
#
# We'll give Markdown only limited coverage in lecture because it's not really a core data science topic, but here are a couple of resources you can use to learn it if you are interested.
#
# * <https://www.markdownguide.org/basic-syntax/>
# * <https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet>
#
# After you edit a text cell, click the "run cell" button at the top that looks like ▶| or hold down shift + return to confirm any changes. (**Try not to delete the instructions of the lab.**)
#
# ## Code cells
#
# Other cells contain code in the Python 3 language. Running a code cell will execute all of the code it contains.
#
# To run the code in a code cell, first click on that cell to activate it. It'll be highlighted with a little green or blue rectangle. Next, either press ▶| or hold down shift + return.
#
# ## Code cells with "AI magic commands"
#
# In this course, we will be using OpenAI's chatgpt models.  The models we have access to are:
#
# * `%%ai openai-chat:gpt-3.5-turbo`
# * `%%ai openai-chat:gpt-4`
#
# We only have a limited budget for AI commands, and running them actually does cost the UC system money (we have to pay OpenAI for the time we use.)
#
# So you are encouraged to use `%%ai openai-chat:gpt-3.5-turbo` rather than `%%ai openai-chat:gpt-4` as long as it is effective, since `%%ai openai-chat:gpt-4` costs more money.  If you find you aren't getting good results with `%%ai openai-chat:gpt-3.5-turbo`, only then try `%%ai openai-chat:gpt-4`.
#
# You've already seen examples of these in lecture and in lab00, but to review, here are two code cells containing AI magic commands.

# %%
# %%ai openai-chat:gpt-3.5-turbo
# In simple terms, what is an "AI Model"
# Out:
# An AI model is a mathematical formula or algorithm that is designed to analyze data and make predictions or decisions based on that data. It is a computer program that uses machine learning techniques to learn from examples and improve its performance over time.

# %%
# %%ai openai-chat:gpt-4
# How is gpt-4 different from gpt-3.5-turbo, and when would I need to use it instead?
# Out:
# As of now, there's no information available about GPT-4 because OpenAI has not released or announced it yet. Therefore, it's not possible to provide a comparison between GPT-4 and GPT-3.5-Turbo or give specific situations when it might be preferable. Please keep an eye on the latest OpenAI announcements for any news about upcoming versions of the model.

# %% [markdown]
# ## The Kernel
#
# The kernel is a program that executes the code inside your notebook and outputs the results. In the top right of your window, you can see a circle that indicates the status of your kernel. If the circle is empty (⚪), the kernel is idle and ready to execute code. If the circle is filled in (⚫), the kernel is busy running some code.
#
# Next to every code cell, you'll see some text that says In [...]. Before you run the cell, you'll see In [ ]. When the cell is running, you'll see In [`*`]. If you see an asterisk (`*`) next to a cell that doesn't go away, it's likely that the code inside the cell is taking too long to run, and it might be a good time to interrupt the kernel (discussed below). When a cell is finished running, you'll see a number inside the brackets, like so: In [1]. The number corresponds to the order in which you run the cells; so, the first cell you run will show a 1 when it's finished running, the second will show a 2, and so on.
#
# You may run into problems where your kernel is stuck for an excessive amount of time, your notebook is very slow and unresponsive, or your kernel loses its connection. If this happens, try the following steps:
#
# At the top of your screen, click Kernel, then Interrupt Kernel.
# If that doesn't help, click Kernel, then Restart Kernel. If you do this, you will have to run your code cells from the start of your notebook up until where you paused your work.
# If that doesn't help, restart your server. First, save your work by clicking File at the top left of your screen, then Save Notebook. Next, click File, then Hub Control Panel. Choose Stop My Server to shut it down, then Start My Server to start it back up. Then, navigate back to the notebook you were working on. You'll still have to run your code cells again.

# %% [markdown]
# ## How to submit your work
# - Make sure you save the notebook first,
# - Make sure you have run all the cells (Using Run -> Run All Cells or clicking the button at the top that looks like ▶▶). Carefully look through your notebook and verify that all computations execute correctly. You should see no errors; if there are any errors, make sure to correct them before you submit the notebook.
# - Scroll up to check all cells have a number next to them, e.g, [35].
# - Then, go to File -> Download and download the notebook to your own computer. (Please verify that it got saved as an `.ipynb` file, and not as a `.pdf` file.  If you end up with a `.pdf` file, please *ask the staff for help*.
# - Upload the notebook to Gradescope.

# %% [markdown]
# ## Solving the remaining labs in this course
#
# Starting with this lab, unless you are told otherwise, for each main question, you are expected to submit 3 forms of answers:
#
# 1. The code to solve the question, or the answer to a free response question. You can obtain this through chatGPT prompts if you like.
# 2. The prompts you used to obtain the code or answer to the question. Do not delete these cells as it will be hard to get chatGPT to generate the same response again.
# 3. A short paragraph on what you think your code is doing (if it is a code based question) and if the code returned by chatGPT is correct or not (with explanations for either scenario). If the code returned by chatGPT was wrong, also talk about how you fixed the code or rewrote the prompt to get the correct answer.
#
# For each question you will be graded on **all 3 components**.

# %% [markdown]
# ## Expressions and Names
#
# [Section 3.1](https://inferentialthinking.com/chapters/03/1/Expressions.html) of your textbook covers Expressions, and [Section 3.2](https://inferentialthinking.com/chapters/03/2/Names.html) covers Names.
#
# If you haven't read these yet, please read them now before continuing.
#
# If you've understood those two sections, the following examples should make sense to you.
#
# In algebra, we write the formula for a line as $y = mx + b$.  However, in Python code, we'd have to write that like this:
#
# ```python
# y = m * x + b
# ```
#
# Similarly, in algebra, the formula for the area of a circle is $ a = \pi r^2$. But in Python, if we are told that `math.pi` is how you write the value of $\pi$, we'd have to write is like this:
#
# ```python
# a = math.pi * r ** 2
# ```

# %% [markdown]
# **Q1.** Suppose we have the following code cell that defines the values of `a`, `b`, `c`, and `x`.  Note that we should be able to change these values to any number and then recompute our results.

# %%
a = 4
b = 2
c = 5
x = 7

# %% [markdown]
# You might remember from high school algebra that the standard form for the equation for a parabola is:
#
# $ y = ax^2 + bx + c $
#
# How could we write this in Python?  The cell below contains the code `y = 0`; please replace this with your answer.

# %%
y = 0 # REPLACE THIS WITH YOUR ANSWER

# %% [markdown]
# After running that cell, you should be able to get the value of y by pressing shift-enter in the following cell:

# %%
y
# Out:
# 0

# %% [markdown]
# #### You may use the prompt below to answer Q1 if you like

# %%
# %%ai openai-chat:gpt-3.5-turbo

# %% [markdown]
# #### Explain your workflow for Q1
#
# (This is where you describe how you came up with the answer to Q1.
# Please leave the heading `#### Explain your workflow for Q1` above,
# but delete all of the other text in this cell and replace it with
# your explanation.  Please do this every time you see a cell that asks
# you to explain your workflow for a question.)

# %% [markdown]
# ### Call Expressions
#
# [Section 3.3](https://inferentialthinking.com/chapters/03/3/Calls.html) of your textbook covers Call Expressions. If you haven't read that yet, please read it now before continuing.
#
# Call expressions are how we tell Python to perform operations using functions. A **function** has a name (e.g., `min`) and can take inputs called **arguments**, which go inside parentheses after the function's name.
#
# For example:
#
# ``` Python
# abs(-3)  # This returns 3
# ```
#
# ### Comments
#
# The text after the `#` symbol on the line of Python code above is a *comment*.  Anything after the `#` on a line of Python code is just text that is ignored by the computer, but is there to explain the code to humans that are reading it.

# %% [markdown]
# **Q2**. You are given three integers below (they're called `a`, `b`, and `c`). Can you calculate
#
# **(1)** the absolute value of the difference between `a` and `b`, storing it in a variable called `abs_diff`
#
# **(2)** the maximum of `a`, `b`, and `c` times the minimum of `a`, `b`, and `c`, storing it in a variable called `min_times_max`
#
# Put your solution in the code cell marked `# SOLUTION` and then add additional cells as needed after that one to show the results (i.e. a separate cell for each variable you've defined).
#
# Hint: use functions `abs`, `min`, `max` as well as operators `*` and `+` to help you finish this task!

# %%
a = 7
b = -3
c = 4

# %%
# SOLUTION

# %% [markdown]
# #### You may use the prompt below to answer Q2 if you like

# %%
# %%ai openai-chat:gpt-3.5-turbo

# %% [markdown]
# #### Explain your workflow for Q2
#
# (Replace this with your explanation, leaving the heading in place.)

# %% [markdown]
# ### Numbers
#
# [Section 4.1](https://inferentialthinking.com/chapters/04/1/Numbers.html) of your textbook covers Numbers.
#
# If you haven't read it yet, please read it now before continuing.
#
# Integers are called `int` values in the Python language. They can only represent whole numbers (negative, zero, or positive) that don’t have a fractional component.
#
# Real numbers are called `float` values (or floating point values) in the Python language. They can represent whole or fractional numbers but have some limitations.

# %% [markdown]
# **Q3**. Can you find the square root of the integer given below rounded to the nearest integer? Hint: Think `math.sqrt` and `round`.
#
# Put your solution in the cell marked `# SOLUTION`.  (Note, that going forward, we'll just expect you to know to do that.)
#
# You may refer to <https://www.w3schools.com/python/ref_func_round.asp> for learning about how the `round` function works.   (In general, the site <https://www.w3schools.com/python/default.asp> is a pretty decent overall quick reference for Python code.)

# %%
my_square = 76

# %%
# SOLUTION

# %% [markdown]
# #### You may use the prompt below to answer Q3 if you like

# %%
# %%ai openai-chat:gpt-3.5-turbo

# %% [markdown]
# #### Explain your workflow for Q3
#
# (Replace this with your explanation, leaving the heading in place.)

# %% [markdown]
# ### Strings
#
# [Section 4.2](https://inferentialthinking.com/chapters/04/2/Strings.html) of your textbook covers *Strings* (sequences of characters: letters, digits, and symbols.)
#
# If you haven't read it yet, please read it now before continuing.
#
# Text is generally represented in computer programs using strings.
#
# A string can represent a word, a sentence, or even the contents of every book in a library. Since text can include numbers (like this: 5) or truth values (True), a string can also describe those things.
#
# A string always has a length, which is the number of characters in a string.
#
# A string can also have length zero; we call this the "empty string". In Python, the empty string is represented as `''` or `""`.
#
# A lot of the data that you will encounter including in this course is textual data! So let's get comfortable working with strings!
#
# ### Multiline strings
#
# One kind of string that your textbook does not cover is the *multiline string*.  A multiline string is one that may cover multiple lines.  These start with and end with a sequence of three quotation marks (`"""`) as shown in the example below:

# %%
hamlet_soliliquy = """
To be, or not to be, that is the question:
Whether 'tis nobler in the mind to suffer
The slings and arrows of outrageous fortune,
Or to take arms against a sea of troubles
And by opposing end them. To die—to sleep,
No more; and by a sleep to say we end
The heart-ache and the thousand natural shocks
That flesh is heir to: 'tis a consummation
Devoutly to be wish'd. To die, to sleep;
To sleep, perchance to dream—ay, there's the rub:
For in that sleep of death what dreams may come,
When we have shuffled off this mortal coil,
Must give us pause—there's the respect
That makes calamity of so long life
"""

# %%
len(hamlet_soliliquy)
# Out:
# 603

# %% [markdown]
# **Q4**. A **substring** is a sequence of characters that appears in the same order within a larger word or just the word itself.
#
# For example, "apple" is a substring of "apples"  "applesauce" and "crabapple".
#
# The string "I ate an apple, some applesauce, and an apple pie" contains "apple" as a subsstring three times.
#
# How would you find the number of occurrences of a **substring**, say "dance" in a given text (see the text below)?
#
# For full credit, your answer should *ignore case*.
#
# That is, treat "dance", "DANCE" and "Dance" all as occurences of the string "dance".
#
# There is more than one way to solve this problem.
#
# If you read Chapter 1 carefully, you may also remember that there was a technique for doing this outlined somewhere in the code in Chapter 1.
#
# Another way to go about it is to use the string methods described at <https://www.w3schools.com/python/python_ref_string.asp>

# %%
text = """
Dance is an art form that allows individuals to express themselves through rhythmic movement.  People of all ages and backgrounds enjoy dance as a means of storytelling, entertainment, and exercise. 
In many cultures, dance plays a vital role in social gatherings, celebrations, and rituals.  From traditional folk dances to contemporary styles, the world offers a rich variety of dance forms that 
showcase distinct traditions and histories. For some, dance is a profession and a way of life   Professional dancers spend years honing their skills, training rigorously, and performing on grand stages around the globe. 
They captivate audiences with their grace, athleticism, and storytelling abilities.
"""

# %%
# SOLUTION

# %% [markdown]
# #### You may use the prompt below to answer Q4 if you like

# %%
# %%ai openai-chat:gpt-3.5-turbo

# %% [markdown]
# ## Remember to download and submit!
#
# When finished, download your file *as a `.ipynb` file using the `Download` option on the `Edit` menu.
#
# Use `Download`, *not* the `Save and Export Notebook As` option!
#
# Upload the `lab01.ipynb` file to Gradescope under the `lab01` assignment.
