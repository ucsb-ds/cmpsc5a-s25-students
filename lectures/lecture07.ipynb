# %%
# Click into this cell and press shift-enter before using this notebook.
# This line loads the ability to use %%ai in your file
# %load_ext jupyter_ai_magics
# These lines import the Python modules we commonly use in CMPSC 5A
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plots

# %% [markdown]
# # Lecture 7, CMPSC 5A, S25
#
# Thu 04/22/2025, Week 4

# %% [markdown]
# ### Note to self: check if font size is readable for back row

# %% [markdown]
# ## Where are we in the reading?
#
# By today, you should have finished reading:
# * [Chapter 1: What is Data Science](https://inferentialthinking.com/chapters/01/what-is-data-science.html)
# * [Chapter 3: Programming in Python](https://inferentialthinking.com/chapters/03/programming-in-python.html)
# * [Chapter 4: Data Types](https://inferentialthinking.com/chapters/04/Data_Types.html)
# * [Chapter 5 (Sequences)](https://inferentialthinking.com/chapters/05/Sequences.html)
# * [Chapter 6 (Tables)](https://inferentialthinking.com/chapters/06/Tables.html)
# * [Chapter 7 (Visualization)](https://inferentialthinking.com/chapters/07/Visualization.html)
# * [Chapter 8 (Functions and Tables: Intro)](https://inferentialthinking.com/chapters/08/Functions_and_Tables.html)
# * [Section 8.1 (Applying a Function to a Column)](https://inferentialthinking.com/chapters/08/1/Applying_a_Function_to_a_Column.html)
#
# For Thursday, please read:
#
# * [Chapter 2 (Causality and Experiments)](https://inferentialthinking.com/chapters/02/causality-and-experiments.html)

# %% [markdown]
# # ic10 (Activity 0): Please join a group on Canvas
#
# If you saw the EdStem post, you've already done this first part.
#
# (Big thank you to those of you that did this before class! It helped me debug the scripts we're using today.)
#
# If you didn't, please do this now:

# %% [markdown]
# 1. Please access the course on canvas.
# 2. Find the "People" item in the side menu, then find a tab for "Groups".
# 3. You should see a page for for "Week-4-Lecture-Groups", with 32 groups that can hold up to 4 people a piece.  Please join one of the groups.
# 4. Optional, but helpful: if you know the people you sit with in class, please join the same group as the people you normally sit with (or: form a group with the people sitting near you.)

# %% [markdown]
# ## ic10: Find your Group Chat on EdStem
#
# Now, go on EdStem, and find your group chat.
#
# It should look like this:
#
# #### Click the Hamburger icon
#
# ![hamburger.jpg](attachment:2c5ab148-5bf7-4851-a237-487f89ad7bce.jpg)
#
# #### Click the chat icon
#
# ![chat.jpg](attachment:d6ca9011-4f44-47e4-a4ae-cdfcedc920dc.jpg)
#
# #### Find your channel ![channels.png](attachment:462af4a8-1b8d-4f7b-b68b-95ce151f5621.png)

# %% [markdown]
# #### In your chat channel
#
# Say hello, and give your name.
#
# Decide who will be (by the order in which you say hello):
# * Person 1
# * Person 2
# * Person 3
# * Person 4
#
# You'll need to know which team member you are for the next steps.
#
# Also, choose a group leader.  That's the person that will submit everything on your behalf today on Gradescope.
#
# # ic10 (Activities 1-5): Look for folder on Google Drive
#
# Now, go to Google Drive, under shared with me:
# * <https://drive.google.com/drive/shared-with-me>
#
# Look for a folder called "CS5A S25 ic10" (if you see versions called "test", ignore those).
#
# Inside that folder, there should be a Jupyter Notebook called `CS5A-S25-ic10.ipynb`
#
# Please make a copy of that for yourself!
#
# There should be five notebooks: the original plus copies for each person, with names like:
# * `CS5A-S25-ic10-Person1-Chris.ipynb`
# * `CS5A-S25-ic10-Person2-Pat.ipynb`
# * `CS5A-S25-ic10-Person3-Austin.ipynb`
# * `CS5A-S25-ic10-Person4-Julia.ipynb`
#
# Then, open up *your* notebook and work on Activities 1-5, using *your* cells (the ones marked Person 1, or Person 2, etc.)
#
# # ic10: Final submission
#
# Now, ONE person per group: copy/paste the answers from the other team members into your own notebook.
#
# You want a combined notebook with everyone's work.
#
# Then submit this for ic10 on Gradescope, as a group assignment.
#
# You'll need to select the other team members when you submit.
